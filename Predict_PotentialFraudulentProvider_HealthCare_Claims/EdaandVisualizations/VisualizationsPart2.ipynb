# %% [markdown]
# #Part -2:Visualizations

# %%
# First, we'll import pandas, a data processing and CSV file I/O library
import pandas as pd

# We'll also import seaborn, a Python graphing library
import warnings 
warnings.filterwarnings("ignore")
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="white", color_codes=True)

# Next, we'll load the FinalMergeData dataset
data = pd.read_csv("FinalMergeData.csv") 

# Let's check the data
data.head()
# Out:
#    Provider      BeneID    ClaimID  InscClaimAmtReimbursed AttendingPhysician  \
# 0  PRV51001   BENE86784  CLM119495                      10          PHY350459
# 1  PRV51001  BENE130029  CLM262535                      90          PHY409648
# 2  PRV51001  BENE102690   CLM49733                   42000          PHY383193
# 3  PRV51001   BENE38773   CLM52334                   12000          PHY346762
# 4  PRV51001   BENE32715  CLM272936                     500          PHY318842
#
#   OperatingPhysician OtherPhysician ClmDiagnosisCode_1 ClmDiagnosisCode_2  \
# 0             NotApp      PHY350459               2767             NotApp
# 1             NotApp      PHY409648              56989             NotApp
# 2          PHY378091      PHY389113               4241              42731
# 3             NotApp         NotApp               0388               5849
# 4          PHY392882         NotApp              78964               V442
#
# ...

# %%
#check the type of data
data.dtypes
# Out:
# Provider                           object
# BeneID                             object
# ClaimID                            object
# InscClaimAmtReimbursed              int64
# AttendingPhysician                 object
# OperatingPhysician                 object
# OtherPhysician                     object
# ClmDiagnosisCode_1                 object
# ClmDiagnosisCode_2                 object
# ClmDiagnosisCode_3                 object
# ClmDiagnosisCode_4                 object
# ClmDiagnosisCode_5                 object
# ClmDiagnosisCode_6                 object
# ClmDiagnosisCode_7                 object
# ClmDiagnosisCode_8                 object
# ClmDiagnosisCode_9                 object
# ClmDiagnosisCode_10                object
# ClmProcedureCode_1                 object
# ClmProcedureCode_2                 object
# ClmProcedureCode_3                 object
# ClmProcedureCode_4                 object
# ClmProcedureCode_5                 object
# ...

# %%
data.describe()
# Out:
#        InscClaimAmtReimbursed  DeductibleAmtPaid  ClaimDuration  \
# count           558211.000000      558211.000000  558211.000000
# mean               997.012133          78.294788       1.727940
# std               3821.534891         273.814128       4.904984
# min                  0.000000           0.000000       0.000000
# 25%                 40.000000           0.000000       0.000000
# 50%                 80.000000           0.000000       0.000000
# 75%                300.000000           0.000000       0.000000
# max             125000.000000        1068.000000      36.000000
#
#         DaysAdmitted         Gender           Race          State  \
# count  558211.000000  558211.000000  558211.000000  558211.000000
# mean        0.410762       1.578838       1.255011      25.446969
# std         2.112693       0.493746       0.717437      15.192784
# min         0.000000       1.000000       1.000000       1.000000
# ...

# %%
#Load the original providers with target data
providerfraud=pd.read_csv("Train-1542865627584.csv")

# %%
target_count1 = providerfraud['PotentialFraud'].value_counts()
print('Class No:', target_count1[0])
print('Class Yes:', target_count1[1])
print('Proportion:', round(target_count1[1] / target_count1[0], 2), ': 1')

target_count1.plot(kind='bar', title='Count (PotentialFraud)');
# Out:
# Class No: 4904
# Class Yes: 506
# Proportion: 0.1 : 1

# %% [markdown]
# Observations:There is class imbalance,there are 506 providers which are fraudulent out of 5410 providers

# %%
target_count = data['PotentialFraud'].value_counts()
print('Class No:', target_count[0])
print('Class Yes:', target_count[1])
print('Proportion:', round(target_count[1] / target_count[0], 2), ': 1')

target_count.plot(kind='bar', title='Count (PotentialFraud)');
# Out:
# Class No: 345415
# Class Yes: 212796
# Proportion: 0.62 : 1

# %% [markdown]
# Observations:There is class imbalance in the data with proportions 0.62:1

# %%
# We'll use seaborn's FacetGrid to color the scatterplot by PotentialFraud
sns.FacetGrid(data, hue="PotentialFraud", size=5) \
   .map(plt.scatter, "DaysAdmitted", "ClaimDuration") \
   .add_legend()
# Out:
# C:\Users\Hai\Anaconda\lib\site-packages\seaborn\axisgrid.py:230: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# Plot Explaination:
# We have plotted the newly generated features DaysAdmitted vs ClaimDuration wrt target classes(PotentialFraud)
#
# Observations:
# We see the Number of fraudulant claims are more when ClaimDurations are greater than 0 and No.of days admitted=0(That is for an inpatient ClaimDuration being of a higher value can be an indicator for fraud)

# %%
 data["ChronicCond_KidneyDisease"]=data["ChronicCond_KidneyDisease"].astype('category')
g = sns.catplot(x="ChronicCond_KidneyDisease", hue="PotentialFraud", col="RenalDiseaseIndicator",
                data=data, kind="count",
                 height=4, aspect=.7);
g

# %% [markdown]
# Plot Explaination:
# We see the two features RenalDiseaseIndicator and ChronicCond_KidneyDisease will be dependent on each other
# ie,if ChronicCond_KidneyDisease is 1 then RenalDiseaseIndicator should be Y and vice versa
#
# Observation:
# There are more chances for a claim to be fraud if the above condition is not satisfied.

# %%
 data["ChronicCond_Alzheimer"]=data["ChronicCond_Alzheimer"].astype('category')
data["ChronicCond_Heartfailure"]=data["ChronicCond_Heartfailure"].astype('category')
 data["ChronicCond_KidneyDisease"]=data["ChronicCond_KidneyDisease"].astype('category')
data["ChronicCond_Cancer"]=data["ChronicCond_Cancer"].astype('category')
data["ChronicCond_ObstrPulmonary"]=data["ChronicCond_ObstrPulmonary"].astype('category')
data["ChronicCond_Depression"]=data["ChronicCond_Depression"].astype('category')
data["ChronicCond_Diabetes"]=data["ChronicCond_Diabetes"].astype('category')
data["ChronicCond_IschemicHeart"]=data["ChronicCond_IschemicHeart"].astype('category')
data["ChronicCond_Osteoporasis"]=data["ChronicCond_Osteoporasis"].astype('category')
data["ChronicCond_rheumatoidarthritis"]=data["ChronicCond_rheumatoidarthritis"].astype('category')
data["ChronicCond_stroke"]=data["ChronicCond_stroke"].astype('category')
data.dtypes
# Out:
# Provider                             object
# BeneID                               object
# ClaimID                              object
# InscClaimAmtReimbursed                int64
# AttendingPhysician                   object
# OperatingPhysician                   object
# OtherPhysician                       object
# ClmDiagnosisCode_1                   object
# ClmDiagnosisCode_2                   object
# ClmDiagnosisCode_3                   object
# ClmDiagnosisCode_4                   object
# ClmDiagnosisCode_5                   object
# ClmDiagnosisCode_6                   object
# ClmDiagnosisCode_7                   object
# ClmDiagnosisCode_8                   object
# ClmDiagnosisCode_9                   object
# ClmDiagnosisCode_10                  object
# ClmProcedureCode_1                   object
# ClmProcedureCode_2                   object
# ClmProcedureCode_3                   object
# ClmProcedureCode_4                   object
# ...

# %%
g = sns.catplot(x="ChronicCond_Diabetes", hue="PotentialFraud", col="ChronicCond_Heartfailure",
                data=data, kind="count",
                 height=4, aspect=.7);
g

# %% [markdown]
# #Numeric data distribution

# %%
list(set(data.dtypes.tolist()))
# Out:
# [dtype('O'),
#  dtype('int64'),
#  CategoricalDtype(categories=[1, 2], ordered=False)]

# %%
df_num = data.select_dtypes(include = ['float64', 'int64'])
df_num.head()
# Out:
#    InscClaimAmtReimbursed  DeductibleAmtPaid  ClaimDuration  DaysAdmitted  \
# 0                      10                  0              0             0
# 1                      90                  0              0             0
# 2                   42000               1068             14            14
# 3                   12000               1068              2             2
# 4                     500                  0              1             0
#
#    Gender  Race  State  County  NoOfMonths_PartACov  NoOfMonths_PartBCov  \
# 0       2     1      1     440                   12                   12
# 1       2     1      1     660                   12                   12
# 2       2     1      1     160                   12                   12
# 3       1     1      1     160                   12                   12
# 4       1     1      1     410                   12                   12
#
#    IPAnnualReimbursementAmt  IPAnnualDeductibleAmt  OPAnnualReimbursementAmt  \
# ...

# %%
df_num.hist(figsize=(16, 20), bins=50, xlabelsize=8, ylabelsize=8); # ;

# %% [markdown]
# Correlation

# %%
import seaborn as sns
corr = data.corr()
sns.heatmap(corr, 
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)

# %% [markdown]
# Observations:
# Strong Correlations between (InscClaimAmtReimbursed,DeductibleAmtPaid) ,
# (DaysAdmitted,InscClaimAmtReimbursed),(DaysAdmitted,DeductibleAmtPaid),(IPAnnualDeductibleAmt ,IPAnnualReimbursementAmt)

# %%
# Bar Plot
fig = plt.figure(figsize = (6, 4))
title = fig.suptitle("Potential Fraud Frequency", fontsize=14)
fig.subplots_adjust(top=0.85, wspace=0.3)

ax = fig.add_subplot(1,1, 1)
ax.set_xlabel("PotentialFraud")
ax.set_ylabel("Frequency") 
w_q = data['PotentialFraud'].value_counts()
w_q = (list(w_q.index), list(w_q.values))
ax.tick_params(axis='both', which='major', labelsize=8.5)
bar = ax.bar(w_q[0], w_q[1], color='steelblue', 
        edgecolor='black', linewidth=1)

# %%
# Correlation Matrix Heatmap
f, ax = plt.subplots(figsize=(10, 6))
corr = data.corr()
hm = sns.heatmap(round(corr,2), annot=True, ax=ax, cmap="coolwarm",fmt='.2f',
                 linewidths=.05)
f.subplots_adjust(top=0.93)
t= f.suptitle('Merged Data Attributes Correlation Heatmap', fontsize=14)

# %% [markdown]
# Observations: Strong Correlations between (InscClaimAmtReimbursed,DeductibleAmtPaid) , (DaysAdmitted,InscClaimAmtReimbursed),(DaysAdmitted,DeductibleAmtPaid),(IPAnnualDeductibleAmt ,IPAnnualReimbursementAmt)

# %%
sns.scatterplot(x='IPAnnualDeductibleAmt' ,y='IPAnnualReimbursementAmt',hue='PotentialFraud' ,data=data)

# %%
sns.scatterplot(x='DaysAdmitted' ,y='InscClaimAmtReimbursed',hue='PotentialFraud' ,data=data)

# %%
# Bar Plot
fig = plt.figure(figsize = (6, 4))
title = fig.suptitle("NoOfMonths_PartACov Frequency", fontsize=14)
fig.subplots_adjust(top=0.85, wspace=0.3)

ax = fig.add_subplot(1,1, 1)
ax.set_xlabel("NoOfMonths_PartACov")
ax.set_ylabel("Frequency") 
w_q = data['NoOfMonths_PartACov'].value_counts()
w_q = (list(w_q.index), list(w_q.values))
ax.tick_params(axis='both', which='major', labelsize=8.5)
bar = ax.bar(w_q[0], w_q[1], color='steelblue', 
        edgecolor='black', linewidth=1)

# %%
# Bar Plot
fig = plt.figure(figsize = (6, 4))
title = fig.suptitle("NoOfMonths_PartBCov Frequency", fontsize=14)
fig.subplots_adjust(top=0.85, wspace=0.3)

ax = fig.add_subplot(1,1, 1)
ax.set_xlabel("NoOfMonths_PartBCov")
ax.set_ylabel("Frequency") 
w_q = data['NoOfMonths_PartBCov'].value_counts()
w_q = (list(w_q.index), list(w_q.values))
ax.tick_params(axis='both', which='major', labelsize=8.5)
bar = ax.bar(w_q[0], w_q[1], color='steelblue', 
        edgecolor='black', linewidth=1)

# %% [markdown]
# Observations:
# NoOfMonths_PartBCov,NoOfMonths_PartACov have their values only at 12 for all the datapoints(can be dropped for model building)

# %%
with sns.axes_style('white'):
    g = sns.factorplot("BeneAge", data=data, aspect=4.0, kind='count',
                       hue='PotentialFraud')
    g.set_ylabels('Total number of Claims')
# Out:
# C:\Users\Hai\Anaconda\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %% [markdown]
# Observations:Most of the fraudulent claims in the data exists between age group of 65-85.
